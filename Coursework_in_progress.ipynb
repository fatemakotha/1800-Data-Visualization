# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemakotha/1800-Data-Visualization/blob/main/Coursework_in_progress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LINK to all csv files:**
# (https://tinyurl.com/ChrisCoDV/001246895/OutletDailyCustomers.csv)
#
# (https://tinyurl.com/ChrisCoDV/001246895/OutletMarketing.csv)
#
# (https://tinyurl.com/ChrisCoDV/001246895/OutletOverheads.csv)
#
# (https://tinyurl.com/ChrisCoDV/001246895/OutletSize.csv)
#
# (https://tinyurl.com/ChrisCoDV/001246895/OutletStaff.csv)

# %% [markdown]
# #**1. Import all necessary libraries:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
########################################################################################################################################################################################################################

# %% [markdown]
# #**2. Create a DataFrame from Daily Customer Data:**

# %%
daily_cust_data = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletDailyCustomers.csv")
daily_cust_data.head(3)
#Each column is a different outlet of ChrisCo
#Each entry is the number of customers in an outlet in a day
# Out:
#          Date  YGE  AGN  GFA  BSQ  HNV  OZW  OTL   RAN  EHT  ...  YMQ  FZI  \
# 0  2021-01-01   65    0   53  920   60   85   72  2130   77  ...    0   81
# 1  2021-01-02   60    0   69  878   54   72   82  2868   82  ...    0   74
# 2  2021-01-03   69    0   52  736   64   91   75  2222   72  ...    0   76
#
#    LTU  DHJ  EEC  IFI  CGV  CNW  IZX  NLT
# 0   66   81  999   75  881   66   86   52
# 1   78   99  952   82  940   68   84   71
# 2   67   77  896   84  634   70   98   51
#
# [3 rows x 46 columns]

# %%
########################################################################################################################################################################################################################

# %% [markdown]
# #**3. Load all other csv files and store them in a variable:**
# ###Check their data types to check if they are integers, or do you have to convert them:

# %%
outlet_marketing = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletMarketing.csv")
outlet_marketing.head(3)
# Out:
#     Id  Marketing (£)
# 0  YGE           2000
# 1  AGN           1000
# 2  GFA           2000

# %%
outlet_marketing.dtypes
# Out:
# Id               object
# Marketing (£)     int64
# dtype: object

# %%
outlet_overheads = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletOverheads.csv")
outlet_overheads.head(3)
# Out:
#     Id  Overheads (£)
# 0  YGE          99000
# 1  AGN          50000
# 2  GFA          82000

# %%
outlet_overheads.dtypes
# Out:
# Id               object
# Overheads (£)     int64
# dtype: object

# %%
outlet_size = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletSize.csv")
outlet_size.head(3)
# Out:
#     Id  Size (msq)
# 0  YGE         124
# 1  AGN          38
# 2  GFA         169

# %%
outlet_size.dtypes
# Out:
# Id            object
# Size (msq)     int64
# dtype: object

# %%
outlet_staff = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletStaff.csv")
outlet_staff.head(3)
# Out:
#     Id  Staff
# 0  YGE      2
# 1  AGN      1
# 2  GFA      2

# %%
########################################################################################################################################################################################################################

# %% [markdown]
# #**4. Try to combine the last 4 csv information into one DataFrame:**

# %%
outlet_staff.dtypes
# Out:
# Id       object
# Staff     int64
# dtype: object

# %%
staff_col = outlet_staff["Staff"]
staff_col[:3]
# Out:
# 0    2
# 1    1
# 2    2
# Name: Staff, dtype: int64

# %%
merged_df = pd.read_csv("https://tinyurl.com/ChrisCoDV/001246895/OutletMarketing.csv")
merged_df.head(2)
# Out:
#     Id  Marketing (£)
# 0  YGE           2000
# 1  AGN           1000

# %%
########################################################################################################################################################################################################################

# %% [markdown]
# ###**Combine the Outlet Staff with Outlet Marketing:**

# %%
merged_df["Staff"] = outlet_staff["Staff"]
merged_df["Size"] = outlet_size["Size (msq)"]
merged_df["Overheads"] = outlet_overheads["Overheads (£)"]
merged_df.head(3)
# Out:
#     Id  Marketing (£)  Staff  Size  Overheads
# 0  YGE           2000      2   124      99000
# 1  AGN           1000      1    38      50000
# 2  GFA           2000      2   169      82000

# %%
########################################################################################################################################################################################################################

# %% [markdown]
# #**5. Check if there are any missing values in both the DataFrames:**
# ###Number of missing values in each column is shown below:

# %%
daily_cust_data.isna().sum() #We can see that there are no missing values
# Out:
# Date    0
# YGE     0
# AGN     0
# GFA     0
# BSQ     0
# HNV     0
# OZW     0
# OTL     0
# RAN     0
# EHT     0
# ZMY     0
# XSB     0
# NFH     0
# ZYT     0
# DSA     0
# MTE     0
# RFY     0
# HTF     0
# DMN     0
# END     0
# DTO     0
# EYS     0
# LLK     0
# CTH     0
# AYD     0
# DZZ     0
# ZSJ     0
# PLB     0
# HZQ     0
# FTW     0
# BMF     0
# CYK     0
# QZF     0
# MZO     0
# GNL     0
# PFQ     0
# YMQ     0
# FZI     0
# LTU     0
# DHJ     0
# EEC     0
# IFI     0
# CGV     0
# CNW     0
# IZX     0
# NLT     0
# dtype: int64

# %%
merged_df.isna().sum()
# Out:
# Id               0
# Marketing (£)    0
# Staff            0
# Size             0
# Overheads        0
# dtype: int64

# %% [markdown]
# #**5. Plot a Line graph of the Daily Customer Visits dataframe:**

# %%
#Check shape of data
daily_cust_data.shape
# Out:
# (365, 46)

# %%
# daily_cust_data.plot(kind="bar")

# %%
daily_cust_data.plot(figsize=(10, 100), subplots=True, xlabel="Date", ylabel="Customers per day");

# %%
#####################################################################################

# %%
# daily_cust_data.plot(figsize=(10, 100), subplots=True, xlabel="Date", ylabel="No of customers per day". x=daily_cust_data["Date"]);

# %%
# daily_cust_data.plot(kind="line")
# plt.figure(figsize=(10,10))


# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# plt.xlabel('Date', fontsize=14)
# plt.ylabel('Number of Posts', fontsize=14)
# plt.ylim(0, 35000)

# %% [markdown]
# check if dates are datetime module:

# %%
daily_cust_data["Date"].dtype
# Out:
# dtype('O')

# %%
########################################################################################################################################################################

# %%
# merged_df

# %%
merged_df["Marketing (£)"].plot(xlabel="Index (1-44)", ylabel="Marketing (£)");

# %%
merged_df["Staff"].plot(xticks=merged_df["Id"]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in convert_units(self, x)
#    1572         try:
# -> 1573             ret = self.converter.convert(x, self.units, self)
#    1574         except Exception as e:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-117-1e59fc8373d6> in <module>
# ...

# %%
merged_df["Overheads"].plot();

# %%
# plt.plot(x=merged_df["Id"], y=merged_df["Size"]); doesn tnot work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-f87e9097fe4b> in <module>
# ----> 1 plt.plot(x=merged_df["Id"], y=merged_df["Size"]);
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...
