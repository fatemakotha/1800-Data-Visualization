# %% [markdown]
# <a href="https://colab.research.google.com/github/fatemakotha/1800-Data-Visualization/blob/main/Lab_01_Exploration_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exploration B**
# The file world_population.csv (available at https://tinyurl.com/ChrisCoDV/world_population.csv) contains data about population densities from 1960 to 2016. Note this is population density (i.e. the number of people per square kilometer) and not absolute population. So some of the smallest countries have the highest densities.
# Some of the countries in the data have missing for some years (possibly because the country didn’t exist that year or just because the data is missing). For that reason, and because it doesn’t really make sense to add up densities, in the following exploration we will calculate mean (average) population density for each country.
#
# **Therefore you should use .mean() rather than .sum() throughout this exploration.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
####---Set index_col=0 or the page won't load !!!!---####
data = pd.read_csv("https://tinyurl.com/ChrisCoDV/world_population.csv", index_col=0)
#data.index = pd.to_datetime(data.index)
print(data)
print(data.head())
print(data.tail)
print(data.describe())
print(data.sum())
# Out:
#                  Country Code  \
# Country Name
# Aruba                     ABW
# Andorra                   AND
# Afghanistan               AFG
# Angola                    AGO
# Albania                   ALB
# ...                       ...
# Yemen, Rep.               YEM
# South Africa              ZAF
# Congo, Dem. Rep.          COD
# Zambia                    ZMB
# Zimbabwe                  ZWE
#
#                                                      Indicator Name  \
# Country Name
# Aruba             Population density (people per sq. km of land ...
# Andorra           Population density (people per sq. km of land ...
# Afghanistan       Population density (people per sq. km of land ...
# Angola            Population density (people per sq. km of land ...
# Albania           Population density (people per sq. km of land ...
# ...                                                             ...
# Yemen, Rep.       Population density (people per sq. km of land ...
# ...

# %% [markdown]
# **1) The data in this exploration also involves more work to get it into shape so read in the data and wrangle it as follows:
# First, each column contains the data from a particular year, whilst each row contains the data for a country. We would like it the other way around to match the previous examples, so transpose it.**

# %%
data = data.transpose()
print(data)
print(data.head())
print(data.tail)
# Out:
# Country Name                                                Aruba  \
# Country Code                                                  ABW
# Indicator Name  Population density (people per sq. km of land ...
# Indicator Code                                        EN.POP.DNST
# 1960                                                          NaN
# 1961                                                   307.972222
# 1962                                                   312.366667
# 1963                                                   314.983333
# 1964                                                   316.827778
# 1965                                                   318.666667
# 1966                                                   320.622222
# 1967                                                   322.494444
# 1968                                                   324.361111
# 1969                                                   326.244444
# ...

# %% [markdown]
# **1) Next drop the three the initial rows which contain any descriptive data – the rows you need to drop are 'Country Code', 'Indicator Name' and 'Indicator Code'. [Hint: see example 12 for an example of how to drop data but note that because these are rows you will need to use axis=0 rather than axis=1.]**
#
# **How many countries are listed (should be the same as the number of columns).
# **

# %%
selected = ["Country Code", "Indicator Name", "Indicator Code"]
data.drop(selected, axis=0)
data.head()
# Out:
# Country Name                                                Aruba  \
# Country Code                                                  ABW
# Indicator Name  Population density (people per sq. km of land ...
# Indicator Code                                        EN.POP.DNST
# 1960                                                          NaN
# 1961                                                   307.972222
#
# Country Name                                              Andorra  \
# Country Code                                                  AND
# Indicator Name  Population density (people per sq. km of land ...
# Indicator Code                                        EN.POP.DNST
# 1960                                                          NaN
# 1961                                                    30.587234
#
# Country Name                                          Afghanistan  \
# Country Code                                                  AFG
# ...

# %% [markdown]
# **Next sort the countries by their average population density, largest first. Which are the top three countries in terms of average population density? [Hint: use .mean() to do the sorting and then, once you have sorted them, use print(data.mean()) to get a list of countries in order of density.]**

# %%
data = data.reindex(data.mean().sort_values(ascending=False).index, axis=1)
print(data.mean())
print(data.head())
# Out:
# Series([], dtype: float64)
# Empty DataFrame
# Columns: []
# Index: [Country Code, Indicator Name, Indicator Code, 1960, 1961]
# <ipython-input-12-b55607e3bb36>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.reindex(data.mean().sort_values(ascending=False).index, axis=1)

# %% [markdown]
# **3)
# Finally select the top three countries, using column selection by value, and draw a line plot of their population density. If you have done it all correctly the final plot should look something like the one below.
# **

# %%
selected = data.columns[data.mean() > 5000]
data = data[selected]
print(data.head())

data.plot.line()
plt.show()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Country Code, Indicator Name, Indicator Code, 1960, 1961]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-8554a1834c00> in <module>
#       3 print(data.head())
#       4
# ----> 5 data.plot.line()
#       6 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# /usr/local/lib/python3.8/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ...
